# %%
import pickle 
import pandas as pd
from collections import Counter
import numpy as np 
import matplotlib.pyplot as plt

# %%
predictions = '/home/ubuntu/code/libby/pipeline/data/finetuned_may19.pkl'
scene_by_scene_gt = 'alpha/sourceTruth_jeremiah.pkl'
ground_truth_obects = '/home/ubuntu/code/drew/e2e_sam2/data/definitiveObjects_jeremiah.pkl'

# %%
with open(ground_truth_obects, 'rb') as f:
    ground_truth_objects = pickle.load(f)
    print(ground_truth_objects.columns)
# Out:
# Index(['class', 'image_path', 'embedding', 'finetuned_embedding',
#        'human_label', '12labs_text_embedding'],
#       dtype='object')
# /tmp/ipykernel_82609/4176022052.py:2: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   ground_truth_objects = pickle.load(f)

# %%
with open(scene_by_scene_gt, 'rb') as f:
    scene_by_scene = pickle.load(f)
    print(scene_by_scene.columns)
# Out:
# Index(['video', 'second', 'tag', 'frame', 'video_id', 'actual'], dtype='object')
# /tmp/ipykernel_82609/2636816042.py:2: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   scene_by_scene = pickle.load(f)

# %%
with open(predictions, 'rb') as f:
        data = pickle.load(f)
        print(data.columns)
# Out:
# Index(['index', 'video', 'frame', 'owl_label', 'image_path',
#        'finetuned_embedding'],
#       dtype='object')
# /tmp/ipykernel_82609/3101038426.py:2: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   data = pickle.load(f)

# %%
with open(ground_truth_obects, 'rb') as f:
    ground_truth_objects = pickle.load(f)
    print(ground_truth_objects.columns)
# Out:
# Index(['class', 'image_path', 'embedding', 'finetuned_embedding',
#        'human_label', '12labs_text_embedding'],
#       dtype='object')
# /tmp/ipykernel_82609/4176022052.py:2: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   ground_truth_objects = pickle.load(f)

# %%
with open(ground_truth_obects, 'rb') as f:
    ground_truth_objects = pickle.load(f)
    print(ground_truth_objects.columns)
# Out:
# Index(['class', 'image_path', 'embedding', 'finetuned_embedding',
#        'human_label', '12labs_text_embedding'],
#       dtype='object')
# /tmp/ipykernel_82609/4176022052.py:2: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   ground_truth_objects = pickle.load(f)

# %%
with open(ground_truth_obects, 'rb') as f:
    ground_truth_objects = pickle.load(f)
    print(ground_truth_objects.columns)
# Out:
# Index(['class', 'image_path', 'embedding', 'finetuned_embedding',
#        'human_label', '12labs_text_embedding'],
#       dtype='object')
# /tmp/ipykernel_82609/4176022052.py:2: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   ground_truth_objects = pickle.load(f)

# %%
with open(ground_truth_obects, 'rb') as f:
    ground_truth_objects = pickle.load(f)
    print(ground_truth_objects.columns)
# Out:
# Index(['class', 'image_path', 'embedding', 'finetuned_embedding',
#        'human_label', '12labs_text_embedding'],
#       dtype='object')
# /tmp/ipykernel_82609/4176022052.py:2: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   ground_truth_objects = pickle.load(f)

# %%
with open(ground_truth_obects, 'rb') as f:
    ground_truth_objects = pickle.load(f)
    print(ground_truth_objects.columns)
# Out:
# Index(['class', 'image_path', 'embedding', 'finetuned_embedding',
#        'human_label', '12labs_text_embedding'],
#       dtype='object')
# /tmp/ipykernel_82609/4176022052.py:2: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   ground_truth_objects = pickle.load(f)

# %%
with open(ground_truth_obects, 'rb') as f:
    ground_truth_objects = pickle.load(f)
    print(ground_truth_objects.columns)
# Out:
# Index(['class', 'image_path', 'embedding', 'finetuned_embedding',
#        'human_label', '12labs_text_embedding'],
#       dtype='object')
# /tmp/ipykernel_82609/4176022052.py:2: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   ground_truth_objects = pickle.load(f)

# %%
with open(ground_truth_obects, 'rb') as f:
    ground_truth_objects = pickle.load(f)
    print(ground_truth_objects.columns)
# Out:
# Index(['class', 'image_path', 'embedding', 'finetuned_embedding',
#        'human_label', '12labs_text_embedding'],
#       dtype='object')
# /tmp/ipykernel_82609/4176022052.py:2: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   ground_truth_objects = pickle.load(f)

# %%
with open(ground_truth_obects, 'rb') as f:
    ground_truth_objects = pickle.load(f)
    print(ground_truth_objects.columns)
# Out:
# Index(['class', 'image_path', 'embedding', 'finetuned_embedding',
#        'human_label', '12labs_text_embedding'],
#       dtype='object')
# /tmp/ipykernel_82609/4176022052.py:2: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   ground_truth_objects = pickle.load(f)

# %%
with open(ground_truth_obects, 'rb') as f:
    ground_truth_objects = pickle.load(f)
    print(ground_truth_objects.columns)
# Out:
# Index(['class', 'image_path', 'embedding', 'finetuned_embedding',
#        'human_label', '12labs_text_embedding'],
#       dtype='object')
# /tmp/ipykernel_82609/4176022052.py:2: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   ground_truth_objects = pickle.load(f)

# %%
with open(ground_truth_obects, 'rb') as f:
    ground_truth_objects = pickle.load(f)
    print(ground_truth_objects.columns)
# Out:
# Index(['class', 'image_path', 'embedding', 'finetuned_embedding',
#        'human_label', '12labs_text_embedding'],
#       dtype='object')
# /tmp/ipykernel_82609/4176022052.py:2: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   ground_truth_objects = pickle.load(f)

# %%
scene_by_scene_gt =
