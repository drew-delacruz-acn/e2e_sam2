# %%
import pickle 
import pandas as pd
from collections import Counter
import numpy as np 
import matplotlib.pyplot as plt

# %%
ground_truth_images = 'alpha/finetuned_may19.pkl'
scene_by_scene_gt = 'alpha/sourceTruth_jeremiah.pkl'

# %%
with open(scene_by_scene_gt, 'rb') as f:
    scene_by_scene = pickle.load(f)
    print(scene_by_scene.columns)
# Out:
# Index(['video', 'second', 'tag', 'frame', 'video_id', 'actual'], dtype='object')
# /tmp/ipykernel_77199/2636816042.py:2: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   scene_by_scene = pickle.load(f)

# %%
with open(ground_truth_images, 'rb') as f:
        data = pickle.load(f)
        print(data.columns)
# Out:
# Index(['index', 'video', 'frame', 'owl_label', 'image_path',
#        'finetuned_embedding'],
#       dtype='object')
# /tmp/ipykernel_77199/2632248308.py:2: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   data = pickle.load(f)

# %%
scene_by_scene_gt =
